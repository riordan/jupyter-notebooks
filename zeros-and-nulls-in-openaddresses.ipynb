# %%
import os
import pandas as pd
import glob
d = []
for f in os.listdir('/Users/driordan/Data/openaddresses/'):
    if ".csv" in f:
        d.append(f)
for f in d:
    df = pd.read_csv(f, low_memory=False)
    
    print("%s | Null: %s | Zeroes: %s | Total: %s" %(f, len(df.loc[df['NUMBER'].isnull()]), len(df.loc[df['NUMBER']==0]), len(df)))
# Out:
# ar-ba-buenos_aires.csv | Null: 0 | Zeroes: 144 | Total: 555755
# au-queensland.csv | Null: 172016 | Zeroes: 0 | Total: 2439599
# au-tasmania.csv | Null: 0 | Zeroes: 28 | Total: 254653
# au-victoria.csv | Null: 355598 | Zeroes: 0 | Total: 3426983
# be-flanders.csv | Null: 0 | Zeroes: 0 | Total: 3372619
# be-wa-brussels-fr.csv | Null: 0 | Zeroes: 0 | Total: 219595
# be-wa-brussels-nl.csv | Null: 0 | Zeroes: 0 | Total: 219595
# br-es-vitoria.csv | Null: 2479 | Zeroes: 0 | Total: 53115
# ca-ab-calgary.csv | Null: 0 | Zeroes: 0 | Total: 351454
# ca-ab-grande_prairie.csv | Null: 59 | Zeroes: 0 | Total: 10591
# ca-ab-strathcona-county.csv | Null: 0 | Zeroes: 0 | Total: 40783
# ca-bc-kamloops.csv | Null: 0 | Zeroes: 5 | Total: 34032
# ca-bc-kelowna.csv | Null: 206 | Zeroes: 0 | Total: 33594
# ca-bc-langley.csv | Null: 1338 | Zeroes: 0 | Total: 41701
# ca-bc-nanaimo.csv | Null: 1873 | Zeroes: 0 | Total: 32971
# ca-bc-north_cowichan.csv | Null: 1880 | Zeroes: 2 | Total: 15181
# ...
